# %%
from sudoku_player import Player
from sudoku_state import State

# %%
agent = Player()

# %%
st = State(agent)

# %%
st.play(100)
# Out:
# Rounds 0
# {}
# 1
# ------------------
# | 1 |   |   |   |
# ------------------
# | 2 | 3 | 4 | 1 |
# ------------------
# | 3 | 4 | 1 | 2 |
# ------------------
# |   |   |   | 4 |
# ------------------
# 1
# ------------------
# | 1 | 1 |   |   |
# ------------------
# | 2 | 3 | 4 | 1 |
# ------------------
# | 3 | 4 | 1 | 2 |
# ------------------
# |   |   |   | 4 |
# ------------------
# Game ended
# ------------------
# | 1 | 1 |   |   |
# ------------------
# | 2 | 3 | 4 | 1 |
# ------------------
# | 3 | 4 | 1 | 2 |
# ------------------
# |   |   |   | 4 |
# ------------------
# [1. 1. 0. 0. 2. 3. 4. 1. 3. 4. 1. 2. 0. 0. 0. 4.] === -0.18000000000000002
# [1. 0. 0. 0. 2. 3. 4. 1. 3. 4. 1. 2. 0. 0. 0. 4.] === -0.032400000000000005
# *************************Round Ended*************************
# Rounds 1
# {'[1. 1. 0. 0. 2. 3. 4. 1. 3. 4. 1. 2. 0. 0. 0. 4.]': -0.18000000000000002, '[1. 0. 0. 0. 2. 3. 4. 1. 3. 4. 1. 2. 0. 0. 0. 4.]': -0.032400000000000005}
# 1
# ...
